# %%
from sqlalchemy import create_engine


# DB_USER = "your_username"
# DB_PASSWORD = "your_password"
# DB_HOST = "localhost"
# DB_NAME = "ipl"
engine = create_engine(
    f"mysql+pymysql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}/{DB_NAME}"
)
print("Connected Successfully")
# Out:
# Connected Successfully

# %%
import pandas as pd

matches = pd.read_csv(r"C:\Users\asus\Downloads\matches.csv")

matches.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
import pymysql

conn = pymysql.connect(
    host="localhost",
    user="root",
    password="Piyush@125",
    database="ipl_analysis"
)

print("Connected")
# Out:
# Connected

# %%
engine.connect()

# %%
matches.rename(columns={"id": "match_id"}, inplace=True)

# %%
print(matches.columns)
# Out:
# Index(['match_id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='str')

# %%
matches.to_sql(
    name="matches",
    con=engine,
    if_exists="append",
    index=False
)

print("Matches Imported Successfully")
# Out:
# Matches Imported Successfully

# %%
import pandas as pd

deliveries = pd.read_csv(r"C:\Users\asus\Downloads\deliveries.csv\deliveries.csv")

# %%
deliveries.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
deliveries.rename(columns={
    "over": "over_no",
    "ball": "ball_no"
}, inplace=True)

# %%
print(deliveries.columns.tolist())
# Out:
# ['match_id', 'inning', 'batting_team', 'bowling_team', 'over_no', 'ball_no', 'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket', 'player_dismissed', 'dismissal_kind', 'fielder']

# %%
deliveries.to_sql(
    name="deliveries",
    con=engine,
    if_exists="append",
    index=False,
    chunksize=1000
)

print("Deliveries Imported Successfully")
# Out:
# Deliveries Imported Successfully

# %%
import pandas as pd

teams = pd.read_csv(r"C:\Users\asus\Desktop\IPL Data\teams_data.csv")

# %%
teams.head()
# Out:
#    team_id                    team_name team_name_short  \
# 0        1  Royal Challengers Bangalore             RCB
# 1        2          Sunrisers Hyderabad             SRH
# 2        3               Mumbai Indians              MI
# 3        4       Rising Pune Supergiant             RPS
# 4        5                Gujarat Lions              GL
#
#                                            image_url
# 0  https://documents.iplt20.com/ipl/RCB/Logos/Log...
# 1  https://documents.iplt20.com/ipl/SRH/Logos/Log...
# 2  https://documents.iplt20.com/ipl/MI/Logos/Logo...
# 3  https://ipl-stats-sports-mechanic.s3.ap-south-...
# 4  https://ipl-stats-sports-mechanic.s3.ap-south-...

# %%
teams.to_sql(
    name="teams",
    con=engine,
    if_exists="append",
    index=False
)
# Out:
# 16

# %%
players = pd.read_csv(
    r"C:\Users\asus\Desktop\IPL Data\players-data-updated.csv",
    encoding="latin1"
)

# %%
players.head()
# Out:
#    player_id  player_name       bat_style            bowl_style field_pos  \
# 0       6730  Mohsin Khan   Left hand Bat  Left arm Medium fast       NaN
# 1         22  Rashid Khan  Right hand Bat       Legbreak Googly
# 2        590     K Rabada   Left hand Bat        Right arm Fast
# 3       1424      SN Khan  Right hand Bat              Legbreak
# 4        963   MN Samuels  Right hand Bat    Right arm Offbreak
#
#            player_full_name      player_name2  \
# 0               Mohsin Khan       Mohsin Khan
# 1         Rashid Khan Arman       Rashid Khan
# 2             Kagiso Rabada     Kagiso Rabada
# 3     Sarfaraz Naushad Khan  Sarfaraz Naushad
# 4  Marlon Nathaniel Samuels  Marlon Nathaniel
#
#                                         player_image
# 0                                                NaN
# 1  https://www.espncricinfo.com/cricketers/rashid...
# 2  https://ipl-stats-sports-mechanic.s3.ap-south-...
# 3                                                NaN
# ...

# %%
players.to_sql(
    name="players",
    con=engine,
    if_exists="append",
    index=False
)
# Out:
# 772

# %%
len(matches)
# Out:
# 1095

# %%
len(deliveries)
# Out:
# 260920

# %%
len(teams)
# Out:
# 16

# %%
len(players)
# Out:
# 772
